# %%
# using mistree to reorder points 
import matplotlib.pyplot as plt
import numpy as np
import time
from helpers.utils import reorder_points, reorder_MST
import netCDF4 as netcdf

# %%
data = netcdf.Dataset("../../real_data/17_Hoelloch/KellerAquarium/centreline/b0_n000.nc")

# %%
# Out:
# 1

# %%
s = time.time()
reordered = reorder_MST(xy_data)
e = time.time()
timed = e - s
print(f"took {timed:.4f} s")
# Out:
# 1 1289
# took 0.0425 s

# %%
s = time.time()
reordered2 = reorder_points(xy_data, 0)
e = time.time()
timed = e - s
print(f"took {timed:.4f} s")
# Out:
# took 0.2071 s

# %%
# reordered: 

plt.plot(reordered[:, 0], reordered[:, 1])
plt.plot(reordered2[:, 0], reordered2[:, 1])
